# %% [markdown]
# # kmeans
# Investigate the clusters of the clustering algorithm

# %%
import warnings

from classification.clustering.clustering_algorithms import kmeans_clustering
from classification.clustering.config_clustering import *
from classification.database_communication.DatabaseCommunication import DatabaseCommunication
from plotting.plot_networks import *
from plotting.plotting_classification import plot_percentage_of_clusters, \
    plot_stacked_distribution_of_clusters_per_regio_5, plot_bar_distribution_of_clusters_per_regio_5

warnings.filterwarnings('ignore')

# %%
dc = DatabaseCommunication()
df_parameters_of_grids = dc.municipal_register_with_clustering_parameters_for_classification_version()
# Out:
# Database connection is constructed.

# %%
df_parameters_of_grids, representative_networks = kmeans_clustering(df_parameters_of_grids=df_parameters_of_grids,
                                                                    list_of_clustering_parameters=LIST_OF_CLUSTERING_PARAMETERS,
                                                                    n_clusters=N_CLUSTERS_KMEANS)

# %% [markdown]
# plot percentage of clusters

# %%
plot_percentage_of_clusters(df_grid_parameters=df_parameters_of_grids)

# %% [markdown]
# stacked bar plot of distribution of clusters over regio 5

# %%
plot_stacked_distribution_of_clusters_per_regio_5(df_grid_parameters=df_parameters_of_grids)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 plot_stacked_distribution_of_clusters_per_regio_5(df_grid_parameters=df_parameters_of_grids)
#
# File F:\Desktop\pylovo_gitlab\pylovo\plotting\plotting_classification.py:541, in plot_stacked_distribution_of_clusters_per_regio_5(df_grid_parameters)
#     539 labels = [item.get_text() for item in ax.get_xticklabels()]
#     540 labels = ['51 Metropole', '52 Großstadt', '53 Mittelstadt', '54 städt. Raum', '55 dörfl. Raum']
# --> 541 ax.set_xticklabels(labels)
#     542 plt.ylabel('Anteil je Klasse (normiert)')
#     543 sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
#
# File ~\anaconda3\envs\pylovo_2\lib\site-packages\matplotlib\axes\_base.py:74, in _axis_method_wrapper.__set_name__.<locals>.wrapper(self, *args, **kwargs)
#      73 def wrapper(self, *args, **kwargs):
# ---> 74     return get_method(self)(*args, **kwargs)
#
# File ~\anaconda3\envs\pylovo_2\lib\site-packages\matplotlib\_api\deprecation.py:297, in rename_parameter.<locals>.wrapper(*args, **kwargs)
#     292     warn_deprecated(
#     293         since, message=f"The {old!r} parameter of {func.__name__}() "
#     294         f"has been renamed {new!r} since Matplotlib {since}; support "
#     295         f"for the old name will be dropped %(removal)s.")
#     296     kwargs[new] = kwargs.pop(old)
# --> 297 return func(*args, **kwargs)
#
# File ~\anaconda3\envs\pylovo_2\lib\site-packages\matplotlib\axis.py:1969, in Axis.set_ticklabels(self, labels, minor, fontdict, **kwargs)
#    1965 if isinstance(locator, mticker.FixedLocator):
#    1966     # Passing [] as a list of labels is often used as a way to
#    1967     # remove all tick labels, so only error for > 0 labels
#    1968     if len(locator.locs) != len(labels) and len(labels) != 0:
# -> 1969         raise ValueError(
#    1970             "The number of FixedLocator locations"
#    1971             f" ({len(locator.locs)}), usually from a call to"
#    1972             " set_ticks, does not match"
#    1973             f" the number of labels ({len(labels)}).")
#    1974     tickd = {loc: lab for loc, lab in zip(locator.locs, labels)}
#    1975     func = functools.partial(self._format_with_dict, tickd)
#
# ValueError: The number of FixedLocator locations (4), usually from a call to set_ticks, does not match the number of labels (5).

# %% [markdown]
# bar plot of clusters in regio 5 classes side by side

# %%
plot_bar_distribution_of_clusters_per_regio_5(df_grid_parameters=df_parameters_of_grids)

# %% [markdown]
# plot clusters over cluster parameters

# %%
df_pairplot = df_parameters_of_grids[[param1, param2, param3, 'clusters']]
sns.pairplot(data=df_pairplot, hue='clusters', palette=TUMPalette, kind='scatter', plot_kws={'alpha': 0.2})
# plt.savefig('pairplot.pdf', dpi=600, bbox_inches='tight')
